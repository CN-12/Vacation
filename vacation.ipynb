# %% [markdown]
# <a href="https://colab.research.google.com/github/CN-12/vacation/blob/main/vacation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pandas
#다운 받기

# %%
from pandas import pandas as pd

# %%
df = pd.read_csv('/content/안녕.csv', header=0)
df
# Out:
#     이름  나이   직업  사는곳  성
# 0  엄준식  36   코인   동탄  남
# 1  깃허브  24   수집  인터넷  남
# 2  이수리  18   학생   서울  여
# 3  자전거  20  자전거   부산  여

# %%
df = df.set_index('이름')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-39-80ceea8d5ccf> in <module>()
# ----> 1 df = df.set_index('이름')
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    5449
#    5450         if missing:
# -> 5451             raise KeyError(f"None of {missing} are in the columns")
#    5452
#    5453         if inplace:
#
# KeyError: "None of ['이름'] are in the columns"

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, 엄준식 to 자전거
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   나이      4 non-null      int64
#  1   직업      4 non-null      object
#  2   사는곳     4 non-null      object
#  3   성       4 non-null      object
#  4   수입      4 non-null      int64
# dtypes: int64(2), object(3)
# memory usage: 364.0+ bytes

# %%
df['나이'].mean()
# Out:
# 24.5

# %%
searchname = input()
df[searchname]
# Out:
# 수입
# 이름
# 엄준식    10000
# 깃허브        0
# 이수리        0
# 자전거      200
# Name: 수입, dtype: int64

# %%
df['수입'] = [10000, 0, 0, 200]

# %%
df.head()
# Out:
#      나이   직업  사는곳  성     수입
# 이름
# 엄준식  36   코인   동탄  남  10000
# 깃허브  24   수집  인터넷  남      0
# 이수리  18   학생   서울  여      0
# 자전거  20  자전거   부산  여    200

# %%
df.loc['엄준식']
# Out:
# 나이        36
# 직업        코인
# 사는곳       동탄
# 성          남
# 수입     10000
# Name: 엄준식, dtype: object

# %%
df.loc['엄준식', '나이':'직업']
# Out:
# 나이    36
# 직업    코인
# Name: 엄준식, dtype: object

# %%
df[["나이", "직업"]]
# Out:
#      나이   직업
# 이름
# 엄준식  36   코인
# 깃허브  24   수집
# 이수리  18   학생
# 자전거  20  자전거

# %%
df.head()
# Out:
#      나이   직업  사는곳  성     수입
# 이름
# 엄준식  36   코인   동탄  남  10000
# 깃허브  24   수집  인터넷  남      0
# 이수리  18   학생   서울  여      0
# 자전거  20  자전거   부산  여    200

# %%
df2 = df.sort_index(ascending=False).head()
df2
# Out:
#      나이   직업  사는곳  성     수입
# 이름
# 자전거  20  자전거   부산  여    200
# 이수리  18   학생   서울  여      0
# 엄준식  36   코인   동탄  남  10000
# 깃허브  24   수집  인터넷  남      0

# %%
df3 = df.sort_index(ascending=True).head()
df3
# Out:
#      나이   직업  사는곳  성     수입
# 이름
# 깃허브  24   수집  인터넷  남      0
# 엄준식  36   코인   동탄  남  10000
# 이수리  18   학생   서울  여      0
# 자전거  20  자전거   부산  여    200

# %%
df.sort_values("나이", ascending=False)
# Out:
#      나이   직업  사는곳  성     수입
# 이름
# 엄준식  36   코인   동탄  남  10000
# 깃허브  24   수집  인터넷  남      0
# 자전거  20  자전거   부산  여    200
# 이수리  18   학생   서울  여      0

# %%
df.head()
# Out:
#      나이   직업  사는곳  성     수입
# 이름
# 엄준식  36   코인   동탄  남  10000
# 깃허브  24   수집  인터넷  남      0
# 이수리  18   학생   서울  여      0
# 자전거  20  자전거   부산  여    200

# %%
df.sort_values("직업").head().index
# Out:
# Index(['깃허브', '자전거', '엄준식', '이수리'], dtype='object', name='이름')

# %%
list(df[df["성"] == "남"].index)
# Out:
# ['엄준식', '깃허브']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, 엄준식 to 자전거
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   나이      4 non-null      int64
#  1   직업      4 non-null      object
#  2   사는곳     4 non-null      object
#  3   성       4 non-null      object
#  4   수입      4 non-null      int64
# dtypes: int64(2), object(3)
# memory usage: 364.0+ bytes

# %%
직 = ['유직' if item > 0 else "무직" for item in df["수입"]]
직
# Out:
# ['유직', '무직', '무직', '유직']

# %%
df["직"] = 직

# %%
df.head()
# Out:
#      나이   직업  사는곳  성     수입   직
# 이름
# 엄준식  36   코인   동탄  남  10000  유직
# 깃허브  24   수집  인터넷  남      0  무직
# 이수리  18   학생   서울  여      0  무직
# 자전거  20  자전거   부산  여    200  유직

# %%
df.to_csv("/content/바이.csv")
